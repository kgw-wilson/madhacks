# %% [markdown]
# ## kNN Experiments

# %%
import matplotlib.pyplot as plt

# %%
# Data
k_values = [1, 2, 3, 5, 10, 20, 40]
accuracies_routerbench = [74.17, 65.60, 80.32, 82.03, 83.90, 84.11, 84.28]
accuracies_flan_t5 = [81.16, 77.91, 82.65, 82.70, 83.32, 83.28, 83.28]
accuracies_mistralai = [70.30, 59.98, 72.05, 73.46, 83.28, 83.19, 83.28]
accuracies_gpt4 = [77.75, 69.13, 75.00, 79.16, 83.32, 83.32, 83.32]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(k_values, accuracies_routerbench, marker='o', linestyle='-', color='b', label='kNN on input space (RouterBench)')
plt.plot(k_values, accuracies_flan_t5, marker='s', linestyle='-', color='r', label='kNN on output space for FLAN-t5-small')
plt.plot(k_values, accuracies_mistralai, marker='^', linestyle='-', color='g', label='kNN on output space for mistralai/mixtral-8x7b-chat')
plt.plot(k_values, accuracies_gpt4, marker='d', linestyle='-', color='m', label='kNN on output space for gpt-4-1106-preview')

# Labels and Title
plt.xlabel('k', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.title('kNN Experiments', fontsize=14)
plt.xticks(k_values)
plt.grid(alpha=0.5)
plt.legend()

# Show plot
# plt.tight_layout()
plt.show()

# %% [markdown]
# ## k-Means Experiments

# %%
import matplotlib.pyplot as plt

# %%
# Data
n_values = [5, 10, 20, 50, 100, 200, 500, 1000]
exp1 = [54.78, 53.16, 61.94, 72.46, 70.63, 72.46, 72.71, 74.33]
exp2 = [73.21, 73.38, 71.80, 72.25, 71.42, 71.55, 71.67, 71.67]
exp3 = [83.28, 80.82, 79.33, 75.25, 72.63, 74.63, 74.67, 73.88]
exp4 = [83.28, 71.51, 70.72, 75.17, 74.08, 75.79, 76.66, 76.12]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(n_values, exp1, marker='o', linestyle='-', color='b', label='Clustering based on prompt embeddings')
plt.plot(n_values, exp2, marker='s', linestyle='-', color='r', label='Clustering based on FLAN-t5-small response embeddings')
plt.plot(n_values, exp3, marker='^', linestyle='-', color='g', label='Clustering based on mistralai/mixtral-8x7b-chat response embeddings')
plt.plot(n_values, exp4, marker='d', linestyle='-', color='m', label='Clustering based on gpt-4-1106-preview response embeddings')

# Labels and Title
plt.xlabel('n (number of clusters)', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.title('k-Means Experiments', fontsize=14)
plt.xticks(n_values)
plt.grid(alpha=0.5)
plt.legend()

# Show plot
# plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
n_values = [5, 10, 20, 50, 100, 200, 500, 1000]
exp1 = [54.78, 53.16, 61.94, 72.46, 70.63, 72.46, 72.71, 74.33]
exp2 = [73.21, 73.38, 71.80, 72.25, 71.42, 71.55, 71.67, 71.67]
exp3 = [83.28, 80.82, 79.33, 75.25, 72.63, 74.63, 74.67, 73.88]
exp4 = [83.28, 71.51, 70.72, 75.17, 74.08, 75.79, 76.66, 76.12]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(n_values, exp1, marker='o', linestyle='-', color='b', label='Clustering based on prompt embeddings')
plt.plot(n_values, exp2, marker='s', linestyle='-', color='r', label='Clustering based on FLAN-t5-small response embeddings')
plt.plot(n_values, exp3, marker='^', linestyle='-', color='g', label='Clustering based on mistralai/mixtral-8x7b-chat response embeddings')
plt.plot(n_values, exp4, marker='d', linestyle='-', color='m', label='Clustering based on gpt-4-1106-preview response embeddings')

# Labels and Title
plt.xlabel('n (number of clusters)', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.title('k-Means Experiments', fontsize=14)
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.xticks(n_values, labels=n_values)  # Ensure correct labels for log scale
plt.grid(alpha=0.5)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Embedding Diffs - kNN

# %%
import matplotlib.pyplot as plt


# Data
k_values = [1, 2, 3, 5, 10, 20, 40]
accuracies_best_correct = [84.94, 81.95, 86.31, 87.4, 87.98, 87.81, 87.35]
accuracies_flan_t5 = [74.13, 67.05, 79.62, 82.24, 83.49, 83.69, 83.78]
accuracies_mistralai = [75.37, 67.05, 79.37, 81.66, 83.28, 83.74, 83.86]
accuracies_gpt4 = [80.62, 75.71, 83.24, 84.57, 85.4, 86.06, 85.73]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(k_values, accuracies_best_correct, marker='o', linestyle='-', color='b', label='Embedding diff from best correct response embedding')
plt.plot(k_values, accuracies_flan_t5, marker='s', linestyle='-', color='r', label='Embedding diff from FLAN-t5-small response embeddings')
plt.plot(k_values, accuracies_mistralai, marker='^', linestyle='-', color='g', label='Embedding diff from mistralai/mixtral-8x7b-chat response embedding')
plt.plot(k_values, accuracies_gpt4, marker='d', linestyle='-', color='m', label='Embedding diff from gpt-4-1106-preview response embedding')

# Labels and Title
plt.xlabel('k', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.title('kNN on Embedding Diff', fontsize=14)
plt.xticks(k_values)
plt.grid(alpha=0.5)
plt.legend()

# Show plot
# plt.tight_layout()
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/Users/cannon/.vscode/extensions/ms-python.python-2024.20.0-darwin-arm64/python_files/python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# # Embedding Diffs - kMeans

# %%
import matplotlib.pyplot as plt


# Data
n_values = [5, 10, 20, 50, 100, 200, 500, 1000]
accuracies_best_correct = [54.78, 53.16, 61.94, 72.46, 70.63, 72.46, 72.71, 74.33]
accuracies_flan_t5 = [65.39, 34.32, 50.04, 45.63, 76.71, 73.25, 72.59, 76.12]
accuracies_mistralai = [68.43, 65.72, 68.97, 74.29, 76.29, 76.91, 77.25, 74.96]
accuracies_gpt4 = [75.37, 80.74, 81.16, 78.99, 81.36, 77.75, 79.12, 79.70]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(n_values, accuracies_best_correct, marker='o', linestyle='-', color='b', label='Embedding diff from best correct response embedding')
plt.plot(n_values, accuracies_flan_t5, marker='s', linestyle='-', color='r', label='Embedding diff from FLAN-t5-small response embeddings')
plt.plot(n_values, accuracies_mistralai, marker='^', linestyle='-', color='g', label='Embedding diff from mistralai/mixtral-8x7b-chat response embedding')
plt.plot(n_values, accuracies_gpt4, marker='d', linestyle='-', color='m', label='Embedding diff from gpt-4-1106-preview response embedding')

# Labels and Title
plt.xlabel('n (number of clusters)', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.title('k-Means on Embedding Diff', fontsize=14)
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.xticks(n_values, labels=n_values)  # Ensure correct labels for log scale
plt.grid(alpha=0.5)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task Description Embeddings - kNN

# %%
import matplotlib.pyplot as plt


# Data
k_values = [1, 2, 3, 5, 10, 20, 40]
accuracies = [72.25, 63.58, 77.13, 78.66, 81.06, 81.65, 81.65]


# Plot
plt.figure(figsize=(10, 6))
plt.plot(k_values, accuracies, marker='o', linestyle='-', color='b', label='Task descriptions from gpt-3.5-turbo')

# Labels and Title
plt.xlabel('k', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.title('kNN on Task Description Embeddings', fontsize=14)
plt.xticks(k_values)
plt.grid(alpha=0.5)
plt.legend()

# Show plot
# plt.tight_layout()
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/Users/cannon/.vscode/extensions/ms-python.python-2024.20.0-darwin-arm64/python_files/python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 11, in <module>
#   File "/Users/cannon/Desktop/fun/hackathon/venv/lib/python3.11/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Users/cannon/Desktop/fun/hackathon/venv/lib/python3.11/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/cannon/Desktop/fun/hackathon/venv/lib/python3.11/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# # Task Description Embeddings - kMeans

# %%
import matplotlib.pyplot as plt

# Data
n_values = [5, 10, 20, 50, 100, 200, 500, 1000]
accuracies = [47.20, 58.70, 74.14, 60.60, 67.59, 70.07, 71.38, 73.63]


# Plot
plt.figure(figsize=(10, 6))
plt.plot(n_values, accuracies, marker='o', linestyle='-', color='b', label='Task descriptions from gpt-3.5-turbo')

# Labels and Title
plt.xlabel('n (number of clusters)', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.title('k-Means on Task Description Embeddings', fontsize=14)
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.xticks(n_values, labels=n_values)  # Ensure correct labels for log scale
plt.grid(alpha=0.5)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/Users/cannon/.vscode/extensions/ms-python.python-2024.20.0-darwin-arm64/python_files/python_server.py", line 130, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 10, in <module>
#   File "/Users/cannon/Desktop/fun/hackathon/venv/lib/python3.11/site-packages/matplotlib/pyplot.py", line 3794, in plot
#     return gca().plot(
#            ^^^^^^^^^^^
#   File "/Users/cannon/Desktop/fun/hackathon/venv/lib/python3.11/site-packages/matplotlib/axes/_axes.py", line 1779, in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/cannon/Desktop/fun/hackathon/venv/lib/python3.11/site-packages/matplotlib/axes/_base.py", line 296, in __call__
#     yield from self._plot_args(
#                ^^^^^^^^^^^^^^^^
# ...
